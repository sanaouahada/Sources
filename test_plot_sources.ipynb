# %%
import plot_source_events as pse
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# #### Cesium source

# %%
cesium = pse.load_data('data/Cs137.csv')  

pse.plot_xy(cesium, "Cs137")
pse.plot_rz(cesium, "Cs137")
pse.plot_energy_spectrum(cesium, "Cs137")

# %% [markdown]
# ### Barium source

# %%
barium = pse.load_data('data/Ba133.csv')

pse.plot_xy(barium, "Ba133")
pse.plot_rz(barium, "Ba133")
pse.plot_energy_spectrum(barium, "Ba133")

# %% [markdown]
# ### Cobalt source

# %%
barium = pse.load_data('data/Co57.csv')

pse.plot_xy(barium, "Co57")
pse.plot_rz(barium, "Co57")
pse.plot_energy_spectrum(barium, "Co57")
