# %%
import plot_source_events as pse
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from matplotlib import rcParams

plt.rcParams['figure.figsize'] = (8, 6)

# %% [markdown]
# #### Cesium source

# %%
cesium = pse.load_data('data/Cs137_expanded5k.csv')  

pse.plot_xy(cesium, "Cs137")
pse.plot_rz(cesium, "Cs137") 
pse.plot_energy_spectrum(cesium, "Cs137")

# %% [markdown]
# ### Barium source

# %%
barium = pse.load_data('data/Ba133_expanded5k.csv')

pse.plot_xy(barium, "Ba133")
pse.plot_rz(barium, "Ba133")
pse.plot_energy_spectrum(barium, "Ba133")

# %% [markdown]
# ### Cobalt source

# %%
cobalt = pse.load_data('data/Co57_expanded5k.csv')

pse.plot_xy(cobalt, "Co57")
pse.plot_rz(cobalt, "Co57")
pse.plot_energy_spectrum(cobalt, "Co57")
